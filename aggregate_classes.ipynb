# %% [markdown]
# ![image.png](attachment:image.png)

# %%
taxonomia_ataque_dict = {
    'BENIGN'                    : 'BENIGN',
    'Port Scan'                 : 'Port Scan',
    'Brute Force: FTP-Patator'  : 'Brute Force',
    'Brute Force: SSH-Patator'  : 'Brute Force',
    'Web Attack: Brute Force'   : 'Web-Attack' ,
    'Web Attack: XSS'           : 'Web-Attack',
    'Web Attack: Sql Injection' : 'Web-Attack',
    'DoS: Hulk'                 : '(D)DOS',
    'DDoS'                      : '(D)DOS',
    'DoS: GoldenEye'            : '(D)DOS',
    'DoS: Slowloris'            : '(D)DOS',
    'DoS: Slowhttptest'         : '(D)DOS',
    'Botnet'                    : 'Botnet',
    'Infiltration'              : 'Unkown',
    'Heartbleed'                : 'Unkown', 
    } 

high_level_class = lambda ataque_especifico : taxonomia_ataque_dict[ataque_especifico]

# %%
import pandas as pd
import numpy as np

# %%
validation_stage_2 = pd.read_csv("data/validation_stage_2.csv")
validation_stage_2.Label.value_counts().index.to_list()
# Out:
# ['BENIGN',
#  'Port Scan',
#  'Botnet',
#  'Brute Force: FTP-Patator',
#  'Brute Force: SSH-Patator',
#  'Web Attack: Brute Force',
#  'Web Attack: XSS',
#  'DoS: Hulk',
#  'DDoS',
#  'DoS: GoldenEye',
#  'DoS: Slowloris',
#  'DoS: Slowhttptest',
#  'Web Attack: Sql Injection']

# %%
validation_stage_2.Label.apply(high_level_class,)
# Out:
# 0            BENIGN
# 1            BENIGN
# 2            BENIGN
# 3            BENIGN
# 4            BENIGN
#            ...
# 2995    Brute Force
# 2996      Port Scan
# 2997         Botnet
# 2998         Botnet
# 2999     Web-Attack
# Name: Label, Length: 3000, dtype: object
