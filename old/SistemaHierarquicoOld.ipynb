# %% [markdown]
# # Importações

# %%
import os
import re
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.datasets import load_digits
from FirstStage import FirstStage
from SecondStage import SecondStage
from Extension import Extension

from tqdm import tqdm

# %% [markdown]
# # Dados

# %% [markdown]
# ### Carregando os dados

# %%
cic_ids_2017 = pd.read_parquet("data/cic_ids_2017.parquet")
infiltration_2018 = pd.read_parquet("data/infiltration_2018.parquet")
testp = pd.read_parquet("data/test.parquet")
cic_collection = pd.read_parquet("data/cic-collection.parquet")

# %% [markdown]
# Exibindo o **.info()**

# %%
cic_ids_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2830743 entries, 0 to 2830742
# Data columns (total 79 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   Destination Port             int64
#  1   Flow Duration                int64
#  2   Total Fwd Packets            int64
#  3   Total Backward Packets       int64
#  4   Total Length of Fwd Packets  int64
#  5   Total Length of Bwd Packets  int64
#  6   Fwd Packet Length Max        int64
#  7   Fwd Packet Length Min        int64
#  8   Fwd Packet Length Mean       float64
#  9   Fwd Packet Length Std        float64
#  10  Bwd Packet Length Max        int64
#  11  Bwd Packet Length Min        int64
#  12  Bwd Packet Length Mean       float64
#  13  Bwd Packet Length Std        float64
#  14  Flow Bytes/s                 float64
#  15  Flow Packets/s               float64
#  16  Flow IAT Mean                float64
#  17  Flow IAT Std                 float64
#  18  Flow IAT Max                 int64
#  19  Flow IAT Min                 int64
#  20  Fwd IAT Total                int64
#  21  Fwd IAT Mean                 float64
#  22  Fwd IAT Std                  float64
#  23  Fwd IAT Max                  int64
#  24  Fwd IAT Min                  int64
#  25  Bwd IAT Total                int64
#  26  Bwd IAT Mean                 float64
#  27  Bwd IAT Std                  float64
#  28  Bwd IAT Max                  int64
#  29  Bwd IAT Min                  int64
#  30  Fwd PSH Flags                int64
#  31  Bwd PSH Flags                int64
#  32  Fwd URG Flags                int64
#  33  Bwd URG Flags                int64
#  34  Fwd Header Length            int64
#  35  Bwd Header Length            int64
#  36  Fwd Packets/s                float64
#  37  Bwd Packets/s                float64
#  38  Min Packet Length            int64
#  39  Max Packet Length            int64
#  40  Packet Length Mean           float64
#  41  Packet Length Std            float64
#  42  Packet Length Variance       float64
#  43  FIN Flag Count               int64
#  44  SYN Flag Count               int64
#  45  RST Flag Count               int64
#  46  PSH Flag Count               int64
#  47  ACK Flag Count               int64
#  48  URG Flag Count               int64
#  49  CWE Flag Count               int64
#  50  ECE Flag Count               int64
#  51  Down/Up Ratio                int64
#  52  Average Packet Size          float64
#  53  Avg Fwd Segment Size         float64
#  54  Avg Bwd Segment Size         float64
#  55  Fwd Header Length.1          int64
#  56  Fwd Avg Bytes/Bulk           int64
#  57  Fwd Avg Packets/Bulk         int64
#  58  Fwd Avg Bulk Rate            int64
#  59  Bwd Avg Bytes/Bulk           int64
#  60  Bwd Avg Packets/Bulk         int64
#  61  Bwd Avg Bulk Rate            int64
#  62  Subflow Fwd Packets          int64
#  63  Subflow Fwd Bytes            int64
#  64  Subflow Bwd Packets          int64
#  65  Subflow Bwd Bytes            int64
#  66  Init_Win_bytes_forward       int64
#  67  Init_Win_bytes_backward      int64
#  68  act_data_pkt_fwd             int64
#  69  min_seg_size_forward         int64
#  70  Active Mean                  float64
#  71  Active Std                   float64
#  72  Active Max                   int64
#  73  Active Min                   int64
#  74  Idle Mean                    float64
#  75  Idle Std                     float64
#  76  Idle Max                     int64
#  77  Idle Min                     int64
#  78  Label                        object
# dtypes: float64(24), int64(54), object(1)
# memory usage: 1.7+ GB

# %%
infiltration_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127844 entries, 0 to 127843
# Data columns (total 68 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Protocol                  127844 non-null  float64
#  1   Flow Duration             127844 non-null  float64
#  2   Total Fwd Packets         127844 non-null  float64
#  3   Total Backward Packets    127844 non-null  float64
#  4   Fwd Packets Length Total  127844 non-null  float64
#  5   Bwd Packets Length Total  127844 non-null  float64
#  6   Fwd Packet Length Max     127844 non-null  float64
#  7   Fwd Packet Length Min     127844 non-null  float64
#  8   Fwd Packet Length Mean    127844 non-null  float64
#  9   Fwd Packet Length Std     127844 non-null  float64
#  10  Bwd Packet Length Max     127844 non-null  float64
#  11  Bwd Packet Length Min     127844 non-null  float64
#  12  Bwd Packet Length Mean    127844 non-null  float64
#  13  Bwd Packet Length Std     127844 non-null  float64
#  14  Flow Bytes/s              127844 non-null  float64
#  15  Flow Packets/s            127844 non-null  float64
#  16  Flow IAT Mean             127844 non-null  float64
#  17  Flow IAT Std              127844 non-null  float64
#  18  Flow IAT Max              127844 non-null  float64
#  19  Flow IAT Min              127844 non-null  float64
#  20  Fwd IAT Total             127844 non-null  float64
#  21  Fwd IAT Mean              127844 non-null  float64
#  22  Fwd IAT Std               127844 non-null  float64
#  23  Fwd IAT Max               127844 non-null  float64
#  24  Fwd IAT Min               127844 non-null  float64
#  25  Bwd IAT Total             127844 non-null  float64
#  26  Bwd IAT Mean              127844 non-null  float64
#  27  Bwd IAT Std               127844 non-null  float64
#  28  Bwd IAT Max               127844 non-null  float64
#  29  Bwd IAT Min               127844 non-null  float64
#  30  Fwd PSH Flags             127844 non-null  float64
#  31  Fwd Header Length         127844 non-null  float64
#  32  Bwd Header Length         127844 non-null  float64
#  33  Fwd Packets/s             127844 non-null  float64
#  34  Bwd Packets/s             127844 non-null  float64
#  35  Packet Length Min         127844 non-null  float64
#  36  Packet Length Max         127844 non-null  float64
#  37  Packet Length Mean        127844 non-null  float64
#  38  Packet Length Std         127844 non-null  float64
#  39  Packet Length Variance    127844 non-null  float64
#  40  FIN Flag Count            127844 non-null  float64
#  41  SYN Flag Count            127844 non-null  float64
#  42  RST Flag Count            127844 non-null  float64
#  43  PSH Flag Count            127844 non-null  float64
#  44  ACK Flag Count            127844 non-null  float64
#  45  URG Flag Count            127844 non-null  float64
#  46  ECE Flag Count            127844 non-null  float64
#  47  Down/Up Ratio             127844 non-null  float64
#  48  Avg Packet Size           127844 non-null  float64
#  49  Avg Fwd Segment Size      127844 non-null  float64
#  50  Avg Bwd Segment Size      127844 non-null  float64
#  51  Subflow Fwd Packets       127844 non-null  float64
#  52  Subflow Fwd Bytes         127844 non-null  float64
#  53  Subflow Bwd Packets       127844 non-null  float64
#  54  Subflow Bwd Bytes         127844 non-null  float64
#  55  Init Fwd Win Bytes        127844 non-null  float64
#  56  Init Bwd Win Bytes        127844 non-null  float64
#  57  Fwd Act Data Packets      127844 non-null  float64
#  58  Fwd Seg Size Min          127844 non-null  float64
#  59  Active Mean               127844 non-null  float64
#  60  Active Std                127844 non-null  float64
#  61  Active Max                127844 non-null  float64
#  62  Active Min                127844 non-null  float64
#  63  Idle Mean                 127844 non-null  float64
#  64  Idle Std                  127844 non-null  float64
#  65  Idle Max                  127844 non-null  float64
#  66  Idle Min                  127844 non-null  float64
#  67  y                         127844 non-null  object
# dtypes: float64(67), object(1)
# memory usage: 66.3+ MB

# %%
testp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59435 entries, 0 to 59434
# Data columns (total 68 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Protocol                  59435 non-null  float32
#  1   Flow Duration             59435 non-null  float64
#  2   Total Fwd Packets         59435 non-null  float64
#  3   Total Backward Packets    59435 non-null  float64
#  4   Fwd Packets Length Total  59435 non-null  float64
#  5   Bwd Packets Length Total  59435 non-null  float64
#  6   Fwd Packet Length Max     59435 non-null  float32
#  7   Fwd Packet Length Min     59435 non-null  float32
#  8   Fwd Packet Length Mean    59435 non-null  float32
#  9   Fwd Packet Length Std     59435 non-null  float32
#  10  Bwd Packet Length Max     59435 non-null  float32
#  11  Bwd Packet Length Min     59435 non-null  float32
#  12  Bwd Packet Length Mean    59435 non-null  float32
#  13  Bwd Packet Length Std     59435 non-null  float32
#  14  Flow Bytes/s              59435 non-null  float32
#  15  Flow Packets/s            59435 non-null  float32
#  16  Flow IAT Mean             59435 non-null  float32
#  17  Flow IAT Std              59435 non-null  float32
#  18  Flow IAT Max              59435 non-null  float64
#  19  Flow IAT Min              59435 non-null  float64
#  20  Fwd IAT Total             59435 non-null  float64
#  21  Fwd IAT Mean              59435 non-null  float32
#  22  Fwd IAT Std               59435 non-null  float32
#  23  Fwd IAT Max               59435 non-null  float64
#  24  Fwd IAT Min               59435 non-null  float64
#  25  Bwd IAT Total             59435 non-null  float64
#  26  Bwd IAT Mean              59435 non-null  float32
#  27  Bwd IAT Std               59435 non-null  float32
#  28  Bwd IAT Max               59435 non-null  float64
#  29  Bwd IAT Min               59435 non-null  float64
#  30  Fwd PSH Flags             59435 non-null  float32
#  31  Fwd Header Length         59435 non-null  float64
#  32  Bwd Header Length         59435 non-null  float64
#  33  Fwd Packets/s             59435 non-null  float32
#  34  Bwd Packets/s             59435 non-null  float32
#  35  Packet Length Min         59435 non-null  float32
#  36  Packet Length Max         59435 non-null  float32
#  37  Packet Length Mean        59435 non-null  float32
#  38  Packet Length Std         59435 non-null  float32
#  39  Packet Length Variance    59435 non-null  float32
#  40  FIN Flag Count            59435 non-null  float32
#  41  SYN Flag Count            59435 non-null  float32
#  42  RST Flag Count            59435 non-null  float32
#  43  PSH Flag Count            59435 non-null  float32
#  44  ACK Flag Count            59435 non-null  float32
#  45  URG Flag Count            59435 non-null  float32
#  46  ECE Flag Count            59435 non-null  float32
#  47  Down/Up Ratio             59435 non-null  float32
#  48  Avg Packet Size           59435 non-null  float32
#  49  Avg Fwd Segment Size      59435 non-null  float32
#  50  Avg Bwd Segment Size      59435 non-null  float32
#  51  Subflow Fwd Packets       59435 non-null  float64
#  52  Subflow Fwd Bytes         59435 non-null  float64
#  53  Subflow Bwd Packets       59435 non-null  float64
#  54  Subflow Bwd Bytes         59435 non-null  float64
#  55  Init Fwd Win Bytes        59435 non-null  float64
#  56  Init Bwd Win Bytes        59435 non-null  float64
#  57  Fwd Act Data Packets      59435 non-null  float64
#  58  Fwd Seg Size Min          59435 non-null  float64
#  59  Active Mean               59435 non-null  float32
#  60  Active Std                59435 non-null  float32
#  61  Active Max                59435 non-null  float64
#  62  Active Min                59435 non-null  float64
#  63  Idle Mean                 59435 non-null  float32
#  64  Idle Std                  59435 non-null  float32
#  65  Idle Max                  59435 non-null  float64
#  66  Idle Min                  59435 non-null  float64
#  67  Y                         59435 non-null  object
# dtypes: float32(40), float64(27), object(1)
# memory usage: 21.8+ MB

# %% [markdown]
# ### Padronizando e limpando os dados

# %% [markdown]
# #### Concatenando os dados

# %% [markdown]
# Mudando o nome das colunas **y** e **Y** para **Label** em dois dos datagramas, pois são a mesma coisa.

# %%
infiltration_2018.rename(columns={'y': 'Label'}, inplace=True)
testp.rename(columns={'Y': 'Label'}, inplace=True)

# %%
df = pd.concat([cic_ids_2017, infiltration_2018, testp, cic_collection], axis=0)

# %%
# Limpeza
del cic_ids_2017
del infiltration_2018
del testp
del cic_collection

# %%
df = df.reset_index(drop=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12185603 entries, 0 to 12185602
# Data columns (total 90 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   Destination Port             float64
#  1   Flow Duration                float64
#  2   Total Fwd Packets            float64
#  3   Total Backward Packets       float64
#  4   Total Length of Fwd Packets  float64
#  5   Total Length of Bwd Packets  float64
#  6   Fwd Packet Length Max        float64
#  7   Fwd Packet Length Min        float64
#  8   Fwd Packet Length Mean       float64
#  9   Fwd Packet Length Std        float64
#  10  Bwd Packet Length Max        float64
#  11  Bwd Packet Length Min        float64
#  12  Bwd Packet Length Mean       float64
#  13  Bwd Packet Length Std        float64
#  14  Flow Bytes/s                 float64
#  15  Flow Packets/s               float64
#  16  Flow IAT Mean                float64
#  17  Flow IAT Std                 float64
#  18  Flow IAT Max                 float64
#  19  Flow IAT Min                 float64
#  20  Fwd IAT Total                float64
#  21  Fwd IAT Mean                 float64
#  22  Fwd IAT Std                  float64
#  23  Fwd IAT Max                  float64
#  24  Fwd IAT Min                  float64
#  25  Bwd IAT Total                float64
#  26  Bwd IAT Mean                 float64
#  27  Bwd IAT Std                  float64
#  28  Bwd IAT Max                  float64
#  29  Bwd IAT Min                  float64
#  30  Fwd PSH Flags                float64
#  31  Bwd PSH Flags                float64
#  32  Fwd URG Flags                float64
#  33  Bwd URG Flags                float64
#  34  Fwd Header Length            float64
#  35  Bwd Header Length            float64
#  36  Fwd Packets/s                float64
#  37  Bwd Packets/s                float64
#  38  Min Packet Length            float64
#  39  Max Packet Length            float64
#  40  Packet Length Mean           float64
#  41  Packet Length Std            float64
#  42  Packet Length Variance       float64
#  43  FIN Flag Count               float64
#  44  SYN Flag Count               float64
#  45  RST Flag Count               float64
#  46  PSH Flag Count               float64
#  47  ACK Flag Count               float64
#  48  URG Flag Count               float64
#  49  CWE Flag Count               float64
#  50  ECE Flag Count               float64
#  51  Down/Up Ratio                float64
#  52  Average Packet Size          float64
#  53  Avg Fwd Segment Size         float64
#  54  Avg Bwd Segment Size         float64
#  55  Fwd Header Length.1          float64
#  56  Fwd Avg Bytes/Bulk           float64
#  57  Fwd Avg Packets/Bulk         float64
#  58  Fwd Avg Bulk Rate            float64
#  59  Bwd Avg Bytes/Bulk           float64
#  60  Bwd Avg Packets/Bulk         float64
#  61  Bwd Avg Bulk Rate            float64
#  62  Subflow Fwd Packets          float64
#  63  Subflow Fwd Bytes            float64
#  64  Subflow Bwd Packets          float64
#  65  Subflow Bwd Bytes            float64
#  66  Init_Win_bytes_forward       float64
#  67  Init_Win_bytes_backward      float64
#  68  act_data_pkt_fwd             float64
#  69  min_seg_size_forward         float64
#  70  Active Mean                  float64
#  71  Active Std                   float64
#  72  Active Max                   float64
#  73  Active Min                   float64
#  74  Idle Mean                    float64
#  75  Idle Std                     float64
#  76  Idle Max                     float64
#  77  Idle Min                     float64
#  78  Label                        object
#  79  Protocol                     float64
#  80  Fwd Packets Length Total     float64
#  81  Bwd Packets Length Total     float64
#  82  Packet Length Min            float64
#  83  Packet Length Max            float64
#  84  Avg Packet Size              float64
#  85  Init Fwd Win Bytes           float64
#  86  Init Bwd Win Bytes           float64
#  87  Fwd Act Data Packets         float64
#  88  Fwd Seg Size Min             float64
#  89  ClassLabel                   object
# dtypes: float64(88), object(2)
# memory usage: 8.2+ GB

# %% [markdown]
# #### Alterando Labels

# %%
pd.set_option('display.max_rows', 999)
values_count = df['Label'].value_counts()
print(values_count)
# Out:
# Label
# Benign                        7242657
# BENIGN                        2273097
# DDoS-LOIC-HTTP                 575364
# DoS-Hulk                       318740
# DDoS                           256089
# DoS Hulk                       231073
# DDoS-HOIC                      198861
# PortScan                       158930
# Botnet                         146552
# Infilteration                  127844
# DDoS-NTP                       121328
# DDoS-TFTP                       98833
# Bruteforce-SSH                  97260
# Infiltration                    94929
# DoS-Goldeneye                   52324
# DDoS-Syn                        47757
# DDoS-UDP                        28863
# DoS-Slowloris                   15243
# DDoS-MSSQL                      11784
# DoS GoldenEye                   10293
# DDoS-UDPLag                      8452
# FTP-Patator                      7938
# Bruteforce-FTP                   5984
# SSH-Patator                      5897
# DoS slowloris                    5796
# DoS Slowhttptest                 5499
# DoS-Slowhttptest                 5271
# DDoS-Ddossim                     5115
# DDoS-DNS                         3668
# DoS-Slowread                     2786
# Portscan                         2255
# DDoS-LDAP                        2092
# Webattack-bruteforce             2020
# DDoS-SNMP                        2017
# Bot                              1966
# DDoS-Slowloris                   1858
# DoS-Slowheaders                  1649
# Web Attack � Brute Force         1507
# Webattack-XSS                     876
# DoS-Rudy                          699
# DDoS-NetBIOS                      675
# Web Attack � XSS                  652
# DoS-Slowbody                      621
# (D)DOS                            584
# Port Scan                         584
# Brute Force                       584
# Web Attack                        584
# Webattack-SQLi                     99
# Heartbleed                         22
# Web Attack � Sql Injection         21
# DoS-Heartbleed                     11
# Name: count, dtype: int64

# %% [markdown]
# Padronizando labels e corrigindo labels redundantes/repetidas ou com caracteres irreconhecíveis.

# %%
label_changes = {'infilteration':'Infiltration', 
                 'Infilteration':'Infiltration', 
                 'Bot':'Botnet', 
                 'PortScan':'Port Scan', 
                 'Web Attack � Brute Force':'Web Attack-Brute Force', 
                 'Web Attack � XSS':'Web Attack-XSS', 
                 'Web Attack � Sql Injection':'Web Attack-Sql Injection', 
                 'DoS slowloris':'DoS Slowloris', 
                 'Benign':'BENIGN', 
                 'DoS Hulk':'DoS-Hulk', 
                 'DoS-Goldeneye':'DoS-GoldenEye', 
                 'DoS GoldenEye':'DoS-GoldenEye', 
                 'DoS Slowhttptest':'DoS-Slowhttptest', 
                 'DoS Slowloris':'DoS-Slowloris', 
                 'portscan':'Port Scan', 
                 'Webattack-bruteforce':'Web Attack-Bruteforce', 
                 'Webattack-XSS':'Web Attack-XSS', 
                 'Webattack-SQLi':'Web Attack-SQLi'}

df['Label'] = df['Label'].replace(label_changes)

# %% [markdown]
# Decidi dropar as linhas com **Web Attack**, pois tem poucas amostras, além de existirem outras amostras até maiores com web ataques específicos, eu pensei em juntar tudo em **Web Attack**, mas percebi que os ataques são muito diferentes pra classificar tudo como **Web Attack**.

# %%
df.drop(df[df['Label'] == 'Web Attack'].index, inplace=True)

# %% [markdown]
# Removendo a coluna **ClassLabel**, esta coluna exibe o tipo do ataque, mas a coluna **Label** exibe o tipo e o subtipo do ataque, ou seja, é uma redundância.

# %%
df.drop(columns=['ClassLabel'], inplace=True)

# %% [markdown]
# Resultado:

# %%
pd.set_option('display.max_rows', None)
values_count = df['Label'].value_counts()
print(values_count.sort_values())
# Out:
# Label
# DoS-Heartbleed                   11
# Web Attack-Sql Injection         21
# Heartbleed                       22
# Web Attack-SQLi                  99
# Brute Force                     584
# (D)DOS                          584
# DoS-Slowbody                    621
# DDoS-NetBIOS                    675
# DoS-Rudy                        699
# Web Attack-Brute Force         1507
# Web Attack-XSS                 1528
# DoS-Slowheaders                1649
# DDoS-Slowloris                 1858
# DDoS-SNMP                      2017
# Web Attack-Bruteforce          2020
# DDoS-LDAP                      2092
# Portscan                       2255
# DoS-Slowread                   2786
# DDoS-DNS                       3668
# DDoS-Ddossim                   5115
# DoS Slowloris                  5796
# SSH-Patator                    5897
# Bruteforce-FTP                 5984
# FTP-Patator                    7938
# DDoS-UDPLag                    8452
# DoS-Slowhttptest              10770
# DDoS-MSSQL                    11784
# DoS-Slowloris                 15243
# DDoS-UDP                      28863
# DDoS-Syn                      47757
# DoS-GoldenEye                 62617
# Bruteforce-SSH                97260
# DDoS-TFTP                     98833
# DDoS-NTP                     121328
# Botnet                       148518
# Port Scan                    159514
# DDoS-HOIC                    198861
# Infiltration                 222773
# DDoS                         256089
# DoS-Hulk                     549813
# DDoS-LOIC-HTTP               575364
# BENIGN                      9515754
# Name: count, dtype: int64

# %% [markdown]
# #### Registros duplicados

# %%
pd.set_option('display.max_rows', 10) # Retornando a um valor menor na exibição do Pandas

# %%
df[df.duplicated()]
# Out:
#           Destination Port  Flow Duration  Total Fwd Packets  \
# 2109                  80.0           77.0                2.0
# 2257                 443.0            3.0                2.0
# 2749                 443.0           49.0                2.0
# 2862                 443.0            4.0                2.0
# 2877                 443.0            1.0                2.0
# ...                    ...            ...                ...
# 12048726               NaN            1.0                3.0
# 12054681               NaN          158.0                1.0
# 12129925               NaN          644.0                1.0
# 12152448               NaN          428.0                1.0
# 12181575               NaN           11.0                2.0
#
#           Total Backward Packets  Total Length of Fwd Packets  \
# 2109                         0.0                         12.0
# 2257                         0.0                         12.0
# 2749                         0.0                         12.0
# 2862                         0.0                         12.0
# 2877                         0.0                         12.0
# ...                          ...                          ...
# 12048726                     0.0                          NaN
# 12054681                     1.0                          NaN
# 12129925                     1.0                          NaN
# 12152448                     1.0                          NaN
# 12181575                     1.0                          NaN
#
#           Total Length of Bwd Packets  Fwd Packet Length Max  \
# 2109                              0.0                    6.0
# 2257                              0.0                    6.0
# 2749                              0.0                    6.0
# 2862                              0.0                    6.0
# 2877                              0.0                    6.0
# ...                               ...                    ...
# 12048726                          NaN                    6.0
# 12054681                          NaN                    6.0
# 12129925                          NaN                    6.0
# 12152448                          NaN                    6.0
# 12181575                          NaN                    6.0
#
#           Fwd Packet Length Min  Fwd Packet Length Mean  \
# 2109                        6.0                     6.0
# 2257                        6.0                     6.0
# 2749                        6.0                     6.0
# 2862                        6.0                     6.0
# 2877                        6.0                     6.0
# ...                         ...                     ...
# 12048726                    NaN                     6.0
# 12054681                    NaN                     6.0
# 12129925                    NaN                     6.0
# 12152448                    NaN                     6.0
# 12181575                    NaN                     6.0
#
#           Fwd Packet Length Std  ...  Protocol  Fwd Packets Length Total  \
# 2109                        0.0  ...       NaN                       NaN
# 2257                        0.0  ...       NaN                       NaN
# 2749                        0.0  ...       NaN                       NaN
# 2862                        0.0  ...       NaN                       NaN
# 2877                        0.0  ...       NaN                       NaN
# ...                         ...  ...       ...                       ...
# 12048726                    0.0  ...       NaN                      18.0
# 12054681                    0.0  ...       NaN                       6.0
# 12129925                    0.0  ...       NaN                       6.0
# 12152448                    0.0  ...       NaN                       6.0
# 12181575                    0.0  ...       NaN                      12.0
#
#           Bwd Packets Length Total  Packet Length Min  Packet Length Max  \
# 2109                           NaN                NaN                NaN
# 2257                           NaN                NaN                NaN
# 2749                           NaN                NaN                NaN
# 2862                           NaN                NaN                NaN
# 2877                           NaN                NaN                NaN
# ...                            ...                ...                ...
# 12048726                       0.0                NaN                6.0
# 12054681                       6.0                NaN                6.0
# 12129925                       6.0                NaN                6.0
# 12152448                       6.0                NaN                6.0
# 12181575                       6.0                NaN                6.0
#
#           Avg Packet Size  Init Fwd Win Bytes  Init Bwd Win Bytes  \
# 2109                  NaN                 NaN                 NaN
# 2257                  NaN                 NaN                 NaN
# 2749                  NaN                 NaN                 NaN
# 2862                  NaN                 NaN                 NaN
# 2877                  NaN                 NaN                 NaN
# ...                   ...                 ...                 ...
# 12048726              8.0                 0.0                -1.0
# 12054681              9.0                 0.0                 0.0
# 12129925              9.0                 0.0                 0.0
# 12152448              9.0                 0.0                 0.0
# 12181575              8.0                 0.0               254.0
#
#           Fwd Act Data Packets  Fwd Seg Size Min
# 2109                       NaN               NaN
# 2257                       NaN               NaN
# 2749                       NaN               NaN
# 2862                       NaN               NaN
# 2877                       NaN               NaN
# ...                        ...               ...
# 12048726                   2.0              20.0
# 12054681                   0.0              20.0
# 12129925                   0.0              20.0
# 12152448                   0.0              20.0
# 12181575                   1.0              20.0
#
# [334921 rows x 89 columns]

# %% [markdown]
# Exibindo os registros não duplicados

# %%
df[~df.duplicated()]
# Out:
#           Destination Port  Flow Duration  Total Fwd Packets  \
# 0                  54865.0            3.0                2.0
# 1                  55054.0          109.0                1.0
# 2                  55055.0           52.0                1.0
# 3                  46236.0           34.0                1.0
# 4                  54863.0            3.0                2.0
# ...                    ...            ...                ...
# 12185598               NaN     44797921.0                6.0
# 12185599               NaN           49.0                3.0
# 12185600               NaN      1286687.0               41.0
# 12185601               NaN          217.0                2.0
# 12185602               NaN      1387547.0               41.0
#
#           Total Backward Packets  Total Length of Fwd Packets  \
# 0                            0.0                         12.0
# 1                            1.0                          6.0
# 2                            1.0                          6.0
# 3                            1.0                          6.0
# 4                            0.0                         12.0
# ...                          ...                          ...
# 12185598                     5.0                          NaN
# 12185599                     0.0                          NaN
# 12185600                    42.0                          NaN
# 12185601                     1.0                          NaN
# 12185602                    46.0                          NaN
#
#           Total Length of Bwd Packets  Fwd Packet Length Max  \
# 0                                 0.0                    6.0
# 1                                 6.0                    6.0
# 2                                 6.0                    6.0
# 3                                 6.0                    6.0
# 4                                 0.0                    6.0
# ...                               ...                    ...
# 12185598                          NaN                    6.0
# 12185599                          NaN                   45.0
# 12185600                          NaN                  456.0
# 12185601                          NaN                   31.0
# 12185602                          NaN                  456.0
#
#           Fwd Packet Length Min  Fwd Packet Length Mean  \
# 0                           6.0                6.000000
# 1                           6.0                6.000000
# 2                           6.0                6.000000
# 3                           6.0                6.000000
# 4                           6.0                6.000000
# ...                         ...                     ...
# 12185598                    NaN                6.000000
# 12185599                    NaN               25.333334
# 12185600                    NaN               64.975609
# 12185601                    NaN               15.500000
# 12185602                    NaN               66.536583
#
#           Fwd Packet Length Std  ...  Protocol  Fwd Packets Length Total  \
# 0                      0.000000  ...       NaN                       NaN
# 1                      0.000000  ...       NaN                       NaN
# 2                      0.000000  ...       NaN                       NaN
# 3                      0.000000  ...       NaN                       NaN
# 4                      0.000000  ...       NaN                       NaN
# ...                         ...  ...       ...                       ...
# 12185598               0.000000  ...       NaN                      36.0
# 12185599              23.028967  ...       NaN                      76.0
# 12185600             109.864571  ...       NaN                    2664.0
# 12185601              21.920311  ...       NaN                      31.0
# 12185602             110.129944  ...       NaN                    2728.0
#
#           Bwd Packets Length Total  Packet Length Min  Packet Length Max  \
# 0                              NaN                NaN                NaN
# 1                              NaN                NaN                NaN
# 2                              NaN                NaN                NaN
# 3                              NaN                NaN                NaN
# 4                              NaN                NaN                NaN
# ...                            ...                ...                ...
# 12185598                       0.0                NaN                6.0
# 12185599                       0.0                NaN               45.0
# 12185600                    6954.0                NaN              976.0
# 12185601                       6.0                NaN               31.0
# 12185602                    6634.0                NaN              976.0
#
#           Avg Packet Size  Init Fwd Win Bytes  Init Bwd Win Bytes  \
# 0                     NaN                 NaN                 NaN
# 1                     NaN                 NaN                 NaN
# 2                     NaN                 NaN                 NaN
# 3                     NaN                 NaN                 NaN
# 4                     NaN                 NaN                 NaN
# ...                   ...                 ...                 ...
# 12185598         3.818182               256.0               290.0
# 12185599        40.333332               122.0                -1.0
# 12185600       115.879517             29200.0               243.0
# 12185601        22.666666               137.0                 0.0
# 12185602       107.609192             29200.0               243.0
#
#           Fwd Act Data Packets  Fwd Seg Size Min
# 0                          NaN               NaN
# 1                          NaN               NaN
# 2                          NaN               NaN
# 3                          NaN               NaN
# 4                          NaN               NaN
# ...                        ...               ...
# 12185598                   5.0              20.0
# 12185599                   1.0              32.0
# 12185600                  24.0              32.0
# 12185601                   0.0              32.0
# 12185602                  24.0              32.0
#
# [11850098 rows x 89 columns]

# %% [markdown]
# Descartando registros duplicados

# %%
initial_len = df.shape[0]
df = df.drop_duplicates()
print(f'Tamanho inicial: {initial_len}, tamanho final {df.shape[0]} | Descartadas {initial_len - df.shape[0]} duplicadas')

df = df.reset_index(drop=True) # Resetando index
# Out:
# Tamanho inicial: 12185019, tamanho final 11850098 | Descartadas 334921 duplicadas

# %% [markdown]
# #### Registros com valores não finitos

# %%
df_columns_isfinite = np.isfinite(df.drop(['Label'], axis='columns')).all(axis=0)
df_columns_isfinite[df_columns_isfinite == False]
# Out:
# Destination Port               False
# Total Length of Fwd Packets    False
# Total Length of Bwd Packets    False
# Fwd Packet Length Min          False
# Bwd Packet Length Min          False
#                                ...
# Avg Packet Size                False
# Init Fwd Win Bytes             False
# Init Bwd Win Bytes             False
# Fwd Act Data Packets           False
# Fwd Seg Size Min               False
# Length: 41, dtype: bool

# %%
df_rows_isfinite = np.isfinite(df.drop(['Label'], axis='columns')).all(axis=1)
inf_indexes = df_rows_isfinite[df_rows_isfinite == False].index
df.iloc[inf_indexes][['Flow Bytes/s', 'Flow Packets/s']]
# Out:
#           Flow Bytes/s  Flow Packets/s
# 0         4.000000e+06   666666.666700
# 1         1.100917e+05    18348.623850
# 2         2.307692e+05    38461.538460
# 3         3.529412e+05    58823.529410
# 4         4.000000e+06   666666.666700
# ...                ...             ...
# 11850093  8.036087e-01        0.245547
# 11850094  1.551020e+06    61224.489800
# 11850095  7.475011e+03       64.506753
# 11850096  1.705069e+05    13824.884790
# 11850097  6.747159e+03       62.700579
#
# [11850098 rows x 2 columns]

# %% [markdown]
# Transformando valores infinitos no maior valor finito encontrado na coluna, isso é feito para as duas colunas.
#
# Isso é feito porque a quantidade de registros infinitos é insignificante, seria inviável fazer isso em um conjunto de dados com muitos registros infinitos, pois existiriam muitos valores máximos e isso poderia comprometer o treinamento.

# %%
max_finite_flow_packets_per_sec = df[np.isfinite(df['Flow Packets/s'])]['Flow Packets/s'].max()
max_finite_flow_bytes_per_sec = df[np.isfinite(df['Flow Bytes/s'])]['Flow Bytes/s'].max()

df.loc[df['Flow Packets/s'] == np.inf, 'Flow Packets/s'] = max_finite_flow_packets_per_sec
df.loc[df['Flow Bytes/s'] == np.inf, 'Flow Bytes/s'] = max_finite_flow_bytes_per_sec

df = df.reset_index(drop=True) # Resetando index

# %% [markdown]
# #### Registros com valores Null/NaN/NA

# %%
df.columns[df.isna().any(axis=0)]
# Out:
# Index(['Destination Port', 'Total Length of Fwd Packets',
#        'Total Length of Bwd Packets', 'Fwd Packet Length Min',
#        'Bwd Packet Length Min', 'Flow Bytes/s', 'Bwd PSH Flags',
#        'Fwd URG Flags', 'Bwd URG Flags', 'Min Packet Length',
#        'Max Packet Length', 'FIN Flag Count', 'RST Flag Count',
#        'PSH Flag Count', 'ACK Flag Count', 'CWE Flag Count', 'ECE Flag Count',
#        'Down/Up Ratio', 'Average Packet Size', 'Fwd Header Length.1',
#        'Fwd Avg Bytes/Bulk', 'Fwd Avg Packets/Bulk', 'Fwd Avg Bulk Rate',
#        'Bwd Avg Bytes/Bulk', 'Bwd Avg Packets/Bulk', 'Bwd Avg Bulk Rate',
#        'Init_Win_bytes_forward', 'Init_Win_bytes_backward', 'act_data_pkt_fwd',
#        'min_seg_size_forward', 'Protocol', 'Fwd Packets Length Total',
#        'Bwd Packets Length Total', 'Packet Length Min', 'Packet Length Max',
#        'Avg Packet Size', 'Init Fwd Win Bytes', 'Init Bwd Win Bytes',
#        'Fwd Act Data Packets', 'Fwd Seg Size Min'],
#       dtype='object')

# %%
df[df.isna().any(axis=1)][['Flow Bytes/s']]
# Out:
#           Flow Bytes/s
# 0         4.000000e+06
# 1         1.100917e+05
# 2         2.307692e+05
# 3         3.529412e+05
# 4         4.000000e+06
# ...                ...
# 11850093  8.036087e-01
# 11850094  1.551020e+06
# 11850095  7.475011e+03
# 11850096  1.705069e+05
# 11850097  6.747159e+03
#
# [11850098 rows x 1 columns]

# %% [markdown]
# Preenchendo registros NaN/Null/NA com a média dos valores de cada coluna.

# %%
for column in tqdm(df.columns):
    if column != "Label":
        column_median = df[column].median()
        df[column].fillna(column_median, inplace=True)

df = df.reset_index(drop=True) # Resetando index
# Out:
# 100%|██████████| 89/89 [00:09<00:00,  9.85it/s]

# %% [markdown]
# #### Features correlacionadas

# %%
def get_highly_correlated_features(correlation_matrix, threshold):
  correlated_pairs = []
  for i in range(len(correlation_matrix.columns)):
    for j in range(i):
      if abs(correlation_matrix.iloc[i, j]) > threshold:
        pair = (correlation_matrix.columns[i], correlation_matrix.columns[j])
        coefficient = correlation_matrix.iloc[i, j]
        correlated_pairs.append((pair, coefficient))
  return sorted(correlated_pairs, key= lambda pair: pair[1], reverse=True)

# %% [markdown]
# Coletando as features correlacionadas, com o objetivo de evitar a redundância no treinamento do modelo.

# %%
df_without_Label = df.drop('Label', axis='columns')

# %%
corr_matrix = df_without_Label.corr().abs()
correlation_list = get_highly_correlated_features(corr_matrix, 0.95)

# Limpeza
del df_without_Label

# %%
correlation_list[:10]
# Out:
# [(('Avg Bwd Segment Size', 'Bwd Packet Length Mean'), 1.0000000000000009),
#  (('CWE Flag Count', 'Fwd URG Flags'), 1.0),
#  (('Avg Fwd Segment Size', 'Fwd Packet Length Mean'), 1.0),
#  (('Subflow Fwd Packets', 'Total Fwd Packets'), 1.0),
#  (('Subflow Bwd Packets', 'Total Backward Packets'), 1.0),
#  (('Fwd IAT Max', 'Flow IAT Max'), 0.9999870380168029),
#  (('Fwd IAT Total', 'Flow Duration'), 0.999974341814589),
#  (('Fwd IAT Min', 'Flow IAT Min'), 0.9999721070393633),
#  (('Fwd IAT Std', 'Flow IAT Std'), 0.9999326855111909),
#  (('ECE Flag Count', 'RST Flag Count'), 0.9998943214795447)]

# %% [markdown]
# Criando uma lista do que será dropado.

# %%
f2drop = []
for feature_pair, _ in correlation_list:
  if feature_pair[0] not in f2drop and feature_pair[1] not in f2drop:
    f2drop.append(feature_pair[1])

# %% [markdown]
# Exibindo as features correlacionadas.

# %%
f2drop
# Out:
# ['Bwd Packet Length Mean',
#  'Fwd URG Flags',
#  'Fwd Packet Length Mean',
#  'Total Fwd Packets',
#  'Total Backward Packets',
#  'Flow IAT Max',
#  'Flow Duration',
#  'Flow IAT Min',
#  'Flow IAT Std',
#  'RST Flag Count',
#  'Flow IAT Mean',
#  'Subflow Fwd Bytes',
#  'Idle Std',
#  'Subflow Bwd Packets',
#  'Idle Mean',
#  'Bwd Packet Length Max',
#  'Subflow Fwd Packets',
#  'Fwd IAT Std',
#  'Fwd Packet Length Max']

# %% [markdown]
# Adicionando a feature **Destination Port** à lista de features a serem dropadas, porque não existe muita correlação entre o tamanho do número da porta com a função da porta, por exemplo, não existe algo do tipo "portas maiores tem uma função mais pra X, enquanto portas menores servem mais pra Y".

# %%
f2drop += ['Destination Port']

# %% [markdown]
# Removendo as features que atrapalham o modelo de aprendizagem

# %%
df = df.drop(f2drop, axis='columns')

# %% [markdown]
# #### Normalização dos dados

# %%
std_scaler = StandardScaler()
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
df[numeric_cols] = std_scaler.fit_transform(df[numeric_cols])
#df = pd.DataFrame(std_scaler.fit_transform(df), columns=df.columns)

# %% [markdown]
# #### Limpeza de variáveis

# %%
del f2drop
del corr_matrix
del correlation_list
del df_columns_isfinite
del df_rows_isfinite
del inf_indexes
del max_finite_flow_packets_per_sec
del max_finite_flow_bytes_per_sec
del initial_len
del numeric_cols
del std_scaler
del label_changes
del values_count
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 del f2drop
#       2 del corr_matrix
#       3 del correlation_list
#
# NameError: name 'f2drop' is not defined

# %% [markdown]
# ### Dados após o tratamento

# %% [markdown]
# Exibindo o **.describe()**.

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)
df.describe(include='all')
# Out:
#         Total Length of Fwd Packets  Total Length of Bwd Packets  \
# count                  1.185010e+07                 1.185010e+07
# unique                          NaN                          NaN
# top                             NaN                          NaN
# freq                            NaN                          NaN
# mean                   3.598878e-16                 6.283604e-18
# std                    1.000000e+00                 1.000000e+00
# min                   -3.725562e-02                -3.599777e-03
# 25%                   -2.375490e-02                -3.459646e-03
# 50%                   -2.375490e-02                -3.459646e-03
# 75%                   -2.375490e-02                -3.459646e-03
# max                    2.638740e+03                 5.925705e+02
#
#         Fwd Packet Length Min  Fwd Packet Length Std  Bwd Packet Length Min  \
# count            1.185010e+07           1.185010e+07           1.185010e+07
# unique                    NaN                    NaN                    NaN
# top                       NaN                    NaN                    NaN
# freq                      NaN                    NaN                    NaN
# mean            -1.931720e-15           7.328663e-17          -3.679087e-15
# std              1.000000e+00           1.000000e+00           1.000000e+00
# min             -1.993741e-01          -4.382963e-01          -2.560248e-01
# 25%             -1.314311e-01          -4.382963e-01          -2.560248e-01
# 50%             -1.314311e-01          -4.146159e-01          -2.560248e-01
# 75%             -1.314311e-01           2.171433e-01          -2.560248e-01
# max              7.878434e+01           8.174884e+01           7.579533e+01
#
#         Bwd Packet Length Std  Flow Bytes/s  Flow Packets/s  Fwd IAT Total  \
# count            1.185010e+07  1.185010e+07    1.185010e+07   1.185010e+07
# unique                    NaN           NaN             NaN            NaN
# top                       NaN           NaN             NaN            NaN
# freq                      NaN           NaN             NaN            NaN
# mean             6.224711e-16 -1.626620e-17   -5.450207e-17   3.968663e-18
# std              1.000000e+00  1.000000e+00    1.000000e+00   1.000000e+00
# min             -4.440539e-01 -4.090027e+00   -1.441003e+01  -1.589784e+03
# 25%             -4.440539e-01 -4.364084e-02   -1.382484e-01  -2.681793e-02
# 50%             -4.440539e-01 -4.362289e-02   -1.380496e-01  -2.674894e-02
# 75%              2.260318e-01 -4.305010e-02   -1.324598e-01  -1.864446e-02
# max              3.480046e+01  4.559834e+01    2.840528e+01   1.807648e-01
#
#         Fwd IAT Mean   Fwd IAT Max   Fwd IAT Min  Bwd IAT Total  Bwd IAT Mean  \
# count   1.185010e+07  1.185010e+07  1.185010e+07   1.185010e+07  1.185010e+07
# unique           NaN           NaN           NaN            NaN           NaN
# top              NaN           NaN           NaN            NaN           NaN
# freq             NaN           NaN           NaN            NaN           NaN
# mean   -1.386117e-17  2.245536e-18  5.092181e-19  -1.310506e-17 -6.230899e-17
# std     1.000000e+00  1.000000e+00  1.000000e+00   1.000000e+00  1.000000e+00
# min    -3.174802e+03 -1.072876e+03 -1.082751e+03  -3.428937e-01 -1.993493e-01
# 25%    -1.771492e-02 -1.297457e-02 -2.945882e-03  -3.428937e-01 -1.993493e-01
# 50%    -1.764615e-02 -1.293202e-02 -2.945858e-03  -3.428920e-01 -1.993423e-01
# 75%    -1.366623e-02 -7.509514e-03 -2.945538e-03  -3.072512e-01 -1.678611e-01
# max     4.422766e-01  1.269180e+03  1.341969e-01   3.843327e+00  1.688696e+01
#
#          Bwd IAT Std   Bwd IAT Max   Bwd IAT Min  Fwd PSH Flags  \
# count   1.185010e+07  1.185010e+07  1.185010e+07   1.185010e+07
# unique           NaN           NaN           NaN            NaN
# top              NaN           NaN           NaN            NaN
# freq             NaN           NaN           NaN            NaN
# mean   -1.156142e-16  7.252872e-18  2.966866e-17   1.511015e-18
# std     1.000000e+00  1.000000e+00  1.000000e+00   1.000000e+00
# min    -2.542569e-01 -2.772788e-01 -9.564411e-02  -1.920655e-01
# 25%    -2.542569e-01 -2.772788e-01 -9.564411e-02  -1.920655e-01
# 50%    -2.542569e-01 -2.772754e-01 -9.564364e-02  -1.920655e-01
# 75%    -2.310316e-01 -2.287598e-01 -9.561888e-02  -1.920655e-01
# max     1.605842e+01  8.019386e+00  1.859306e+01   5.206558e+00
#
#         Bwd PSH Flags  Bwd URG Flags  Fwd Header Length  Bwd Header Length  \
# count      11850098.0     11850098.0       1.185010e+07       1.185010e+07
# unique            NaN            NaN                NaN                NaN
# top               NaN            NaN                NaN                NaN
# freq              NaN            NaN                NaN                NaN
# mean              0.0            0.0      -1.014539e-17      -2.275217e-18
# std               0.0            0.0       1.000000e+00       1.000000e+00
# min               0.0            0.0      -2.608076e+02      -1.502618e+03
# 25%               0.0            0.0       8.212524e-03       3.754400e-03
# 50%               0.0            0.0       8.212564e-03       3.756521e-03
# 75%               0.0            0.0       8.212681e-03       3.765005e-03
# max               0.0            0.0       1.732361e-01       5.197037e-01
#
#         Fwd Packets/s  Bwd Packets/s  Min Packet Length  Max Packet Length  \
# count    1.185010e+07   1.185010e+07       1.185010e+07       1.185010e+07
# unique            NaN            NaN                NaN                NaN
# top               NaN            NaN                NaN                NaN
# freq              NaN            NaN                NaN                NaN
# mean    -3.917606e-17  -1.764338e-16       3.617149e-15       9.635192e-16
# std      1.000000e+00   1.000000e+00       1.000000e+00       1.000000e+00
# min     -1.273563e-01  -1.143483e-01      -3.885026e-01      -2.906605e-01
# 25%     -1.273489e-01  -1.143422e-01      -2.377819e-01      -1.939554e-01
# 50%     -1.272309e-01  -1.141826e-01      -2.377819e-01      -1.939554e-01
# 75%     -1.238419e-01  -1.108896e-01      -2.377819e-01      -1.939554e-01
# max      3.152293e+01   8.207471e+01       1.087333e+02       2.324090e+01
#
#         Packet Length Mean  Packet Length Std  Packet Length Variance  \
# count         1.185010e+07       1.185010e+07            1.185010e+07
# unique                 NaN                NaN                     NaN
# top                    NaN                NaN                     NaN
# freq                   NaN                NaN                     NaN
# mean         -9.668962e-16      -8.071315e-16           -8.227597e-17
# std           1.000000e+00       1.000000e+00            1.000000e+00
# min          -6.403185e-01      -5.300755e-01           -2.291891e-01
# 25%          -5.475769e-01      -5.225124e-01           -2.291789e-01
# 50%          -3.335577e-01      -4.045132e-01           -2.263682e-01
# 75%           1.466921e-02       1.673368e-01           -1.421626e-01
# max           7.247796e+01       4.922314e+01            4.424192e+02
#
#         FIN Flag Count  SYN Flag Count  PSH Flag Count  ACK Flag Count  \
# count     1.185010e+07    1.185010e+07    1.185010e+07    1.185010e+07
# unique             NaN             NaN             NaN             NaN
# top                NaN             NaN             NaN             NaN
# freq               NaN             NaN             NaN             NaN
# mean      1.451256e-15    1.575773e-18    1.294657e-15    3.799124e-17
# std       1.000000e+00    1.000000e+00    1.000000e+00    1.000000e+00
# min      -8.356312e-02   -2.109413e-01   -2.713442e-01   -2.733082e-01
# 25%      -8.356312e-02   -2.109413e-01   -2.713442e-01   -2.733082e-01
# 50%      -8.356312e-02   -2.109413e-01   -2.713442e-01   -2.733082e-01
# 75%      -8.356312e-02   -2.109413e-01   -2.713442e-01   -2.733082e-01
# max       1.196700e+01    4.740655e+00    3.685356e+00    3.658873e+00
#
#         URG Flag Count  CWE Flag Count  ECE Flag Count  Down/Up Ratio  \
# count     1.185010e+07    1.185010e+07    1.185010e+07   1.185010e+07
# unique             NaN             NaN             NaN            NaN
# top                NaN             NaN             NaN            NaN
# freq               NaN             NaN             NaN            NaN
# mean     -1.414790e-16   -6.432817e-17   -7.652452e-16   1.068062e-15
# std       1.000000e+00    1.000000e+00    1.000000e+00   1.000000e+00
# min      -2.306884e-01   -2.598277e-03   -5.301626e-02  -2.630298e+00
# 25%      -2.306884e-01   -2.598277e-03   -5.301626e-02   1.936165e-01
# 50%      -2.306884e-01   -2.598277e-03   -5.301626e-02   1.936165e-01
# 75%      -2.306884e-01   -2.598277e-03   -5.301626e-02   1.936165e-01
# max       4.334851e+00    3.848704e+02    1.886214e+01   4.379004e+02
#
#         Average Packet Size  Avg Fwd Segment Size  Avg Bwd Segment Size  \
# count          1.185010e+07          1.185010e+07          1.185010e+07
# unique                  NaN                   NaN                   NaN
# top                     NaN                   NaN                   NaN
# freq                    NaN                   NaN                   NaN
# mean           3.411105e-15          4.058874e-16         -1.136782e-15
# std            1.000000e+00          1.000000e+00          1.000000e+00
# min           -6.464832e-01         -4.971481e-01         -5.126030e-01
# 25%           -1.664668e-01         -4.542182e-01         -5.126030e-01
# 50%           -1.664668e-01         -2.266896e-01         -2.826756e-01
# 75%           -1.664668e-01          8.669891e-02         -2.958806e-02
# max            2.249734e+01          1.059432e+02          7.511629e+01
#
#         Fwd Header Length.1  Fwd Avg Bytes/Bulk  Fwd Avg Packets/Bulk  \
# count          1.185010e+07          11850098.0            11850098.0
# unique                  NaN                 NaN                   NaN
# top                     NaN                 NaN                   NaN
# freq                    NaN                 NaN                   NaN
# mean           5.229866e-18                 0.0                   0.0
# std            1.000000e+00                 0.0                   0.0
# min           -3.130547e+03                 0.0                   0.0
# 25%            6.049966e-04                 0.0                   0.0
# 50%            6.049966e-04                 0.0                   0.0
# 75%            6.049966e-04                 0.0                   0.0
# max            4.520144e-01                 0.0                   0.0
#
#         Fwd Avg Bulk Rate  Bwd Avg Bytes/Bulk  Bwd Avg Packets/Bulk  \
# count          11850098.0          11850098.0            11850098.0
# unique                NaN                 NaN                   NaN
# top                   NaN                 NaN                   NaN
# freq                  NaN                 NaN                   NaN
# mean                  0.0                 0.0                   0.0
# std                   0.0                 0.0                   0.0
# min                   0.0                 0.0                   0.0
# 25%                   0.0                 0.0                   0.0
# 50%                   0.0                 0.0                   0.0
# 75%                   0.0                 0.0                   0.0
# max                   0.0                 0.0                   0.0
#
#         Bwd Avg Bulk Rate  Subflow Bwd Bytes  Init_Win_bytes_forward  \
# count          11850098.0       1.185010e+07            1.185010e+07
# unique                NaN                NaN                     NaN
# top                   NaN                NaN                     NaN
# freq                  NaN                NaN                     NaN
# mean                  0.0      -4.572020e-20            2.543744e-15
# std                   0.0       1.000000e+00            1.000000e+00
# min                   0.0      -7.358968e-03           -2.383451e-01
# 25%                   0.0      -7.358968e-03           -2.039272e-01
# 50%                   0.0      -7.230698e-03           -2.039272e-01
# 75%                   0.0      -6.758716e-03           -2.039272e-01
# max                   0.0       4.081219e+02            8.712484e+00
#
#         Init_Win_bytes_backward  act_data_pkt_fwd  min_seg_size_forward  \
# count              1.185010e+07      1.185010e+07          1.185010e+07
# unique                      NaN               NaN                   NaN
# top                         NaN               NaN                   NaN
# freq                        NaN               NaN                   NaN
# mean              -4.660162e-16     -1.834669e-17         -4.201761e-18
# std                1.000000e+00      1.000000e+00          1.000000e+00
# min               -1.127797e-01     -6.640306e-03         -1.012403e+03
# 25%               -1.125427e-01     -3.425495e-03          1.244441e-03
# 50%               -1.125427e-01     -3.425495e-03          1.244441e-03
# 75%               -1.125427e-01     -3.425495e-03          1.244441e-03
# max                1.541988e+01      6.865386e+02          1.466960e-03
#
#          Active Mean    Active Std    Active Max    Active Min      Idle Max  \
# count   1.185010e+07  1.185010e+07  1.185010e+07  1.185010e+07  1.185010e+07
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    5.949562e-17  1.189625e-16 -2.833153e-17 -1.192023e-17 -3.185124e-18
# std     1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min    -8.232329e-02 -6.754923e-02 -1.024218e-01 -6.781397e-02 -1.221315e-02
# 25%    -8.232329e-02 -6.754923e-02 -1.024218e-01 -6.781397e-02 -1.221315e-02
# 50%    -8.232329e-02 -6.754923e-02 -1.024218e-01 -6.781397e-02 -1.221315e-02
# 75%    -8.232329e-02 -6.754923e-02 -1.024218e-01 -6.781397e-02 -1.221315e-02
# max     8.201957e+01  9.285471e+01  6.052134e+01  9.513776e+01  1.338431e+03
#
#             Idle Min     Label      Protocol  Fwd Packets Length Total  \
# count   1.185010e+07  11850098  1.185010e+07              1.185010e+07
# unique           NaN        42           NaN                       NaN
# top              NaN    BENIGN           NaN                       NaN
# freq             NaN   9336752           NaN                       NaN
# mean   -7.823700e-18       NaN  6.002424e-16             -1.287181e-17
# std     1.000000e+00       NaN  1.000000e+00              1.000000e+00
# min    -1.021460e-01       NaN -7.798134e+00             -2.211830e-02
# 25%    -1.021460e-01       NaN -6.860029e-02             -2.156165e-02
# 50%    -1.021460e-01       NaN -6.860029e-02             -2.080136e-02
# 75%    -1.021460e-01       NaN -6.860029e-02             -1.408092e-02
# max     3.185468e+03       NaN  1.410221e+01              1.960335e+03
#
#         Bwd Packets Length Total  Packet Length Min  Packet Length Max  \
# count               1.185010e+07       1.185010e+07       1.185010e+07
# unique                       NaN                NaN                NaN
# top                          NaN                NaN                NaN
# freq                         NaN                NaN                NaN
# mean               -5.600125e-18      -4.800039e-16       2.917201e-16
# std                 1.000000e+00       1.000000e+00       1.000000e+00
# min                -6.877409e-03      -5.894981e-02      -5.512340e-01
# 25%                -6.809563e-03      -5.894981e-02      -4.755358e-01
# 50%                -6.679023e-03      -5.894981e-02      -3.405560e-01
# 75%                -6.377580e-03      -5.894981e-02       3.015101e-01
# max                 5.629050e+02       3.623632e+02       5.887636e+01
#
#         Avg Packet Size  Init Fwd Win Bytes  Init Bwd Win Bytes  \
# count      1.185010e+07        1.185010e+07        1.185010e+07
# unique              NaN                 NaN                 NaN
# top                 NaN                 NaN                 NaN
# freq                NaN                 NaN                 NaN
# mean      -6.462725e-16        1.954630e-16       -2.008931e-16
# std        1.000000e+00        1.000000e+00        1.000000e+00
# min       -7.153695e-01       -5.090679e-01       -3.759625e-01
# 25%       -4.146555e-01       -5.016269e-01       -3.759625e-01
# 50%       -2.300709e-01       -3.889576e-01       -3.688985e-01
# 75%        6.381190e-02       -2.903697e-02       -3.628599e-01
# max        8.474807e+01        3.330711e+00        3.357475e+00
#
#         Fwd Act Data Packets  Fwd Seg Size Min
# count           1.185010e+07      1.185010e+07
# unique                   NaN               NaN
# top                      NaN               NaN
# freq                     NaN               NaN
# mean            1.422273e-18      9.895710e-17
# std             1.000000e+00      1.000000e+00
# min            -1.571682e-02     -4.743985e+01
# 25%            -1.516356e-02      2.794239e-02
# 50%            -1.516356e-02      2.794239e-02
# 75%            -1.461030e-02      2.794239e-02
# max             1.712894e+02      2.294431e+00

# %%
pd.set_option('display.max_columns', 10)
pd.set_option('display.max_rows', 10)

# %% [markdown]
# Exibindo o **.info()**.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11850098 entries, 0 to 11850097
# Data columns (total 69 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   Total Length of Fwd Packets  float64
#  1   Total Length of Bwd Packets  float64
#  2   Fwd Packet Length Min        float64
#  3   Fwd Packet Length Std        float64
#  4   Bwd Packet Length Min        float64
#  5   Bwd Packet Length Std        float64
#  6   Flow Bytes/s                 float64
#  7   Flow Packets/s               float64
#  8   Fwd IAT Total                float64
#  9   Fwd IAT Mean                 float64
#  10  Fwd IAT Max                  float64
#  11  Fwd IAT Min                  float64
#  12  Bwd IAT Total                float64
#  13  Bwd IAT Mean                 float64
#  14  Bwd IAT Std                  float64
#  15  Bwd IAT Max                  float64
#  16  Bwd IAT Min                  float64
#  17  Fwd PSH Flags                float64
#  18  Bwd PSH Flags                float64
#  19  Bwd URG Flags                float64
#  20  Fwd Header Length            float64
#  21  Bwd Header Length            float64
#  22  Fwd Packets/s                float64
#  23  Bwd Packets/s                float64
#  24  Min Packet Length            float64
#  25  Max Packet Length            float64
#  26  Packet Length Mean           float64
#  27  Packet Length Std            float64
#  28  Packet Length Variance       float64
#  29  FIN Flag Count               float64
#  30  SYN Flag Count               float64
#  31  PSH Flag Count               float64
#  32  ACK Flag Count               float64
#  33  URG Flag Count               float64
#  34  CWE Flag Count               float64
#  35  ECE Flag Count               float64
#  36  Down/Up Ratio                float64
#  37  Average Packet Size          float64
#  38  Avg Fwd Segment Size         float64
#  39  Avg Bwd Segment Size         float64
#  40  Fwd Header Length.1          float64
#  41  Fwd Avg Bytes/Bulk           float64
#  42  Fwd Avg Packets/Bulk         float64
#  43  Fwd Avg Bulk Rate            float64
#  44  Bwd Avg Bytes/Bulk           float64
#  45  Bwd Avg Packets/Bulk         float64
#  46  Bwd Avg Bulk Rate            float64
#  47  Subflow Bwd Bytes            float64
#  48  Init_Win_bytes_forward       float64
#  49  Init_Win_bytes_backward      float64
#  50  act_data_pkt_fwd             float64
#  51  min_seg_size_forward         float64
#  52  Active Mean                  float64
#  53  Active Std                   float64
#  54  Active Max                   float64
#  55  Active Min                   float64
#  56  Idle Max                     float64
#  57  Idle Min                     float64
#  58  Label                        object
#  59  Protocol                     float64
#  60  Fwd Packets Length Total     float64
#  61  Bwd Packets Length Total     float64
#  62  Packet Length Min            float64
#  63  Packet Length Max            float64
#  64  Avg Packet Size              float64
#  65  Init Fwd Win Bytes           float64
#  66  Init Bwd Win Bytes           float64
#  67  Fwd Act Data Packets         float64
#  68  Fwd Seg Size Min             float64
# dtypes: float64(68), object(1)
# memory usage: 6.1+ GB

# %% [markdown]
# # Dividindo os dados (treino, validação, teste)

# %%
df_train = df.query('Label == "BENIGN"').sample(frac=0.6)#, random_state=RANDOM_SEED)
df_val_test = df.drop(df_train.index)

df_train = df_train.reset_index(drop=True)
df_val_test = df_val_test.reset_index(drop=True)

X_train = df_train.drop('Label', axis='columns')

# %%
del df

# %%
X_val, X_test, classes_val, classes_test = train_test_split(df_val_test.drop('Label', axis='columns'), df_val_test['Label'], test_size=0.65, stratify=df_val_test['Label']) #random_state=RANDOM_SEED)

X_val, X_test = X_val.reset_index(drop=True), X_test.reset_index(drop=True)
classes_val, classes_test =  classes_val.reset_index(drop=True), classes_test.reset_index(drop=True)

y_val, y_test = classes_val.apply(lambda c: 0 if c == 'BENIGN' else 1), classes_test.apply(lambda c: 0 if c == 'BENIGN' else 1)

# %%
del df_train, df_val_test

# %% [markdown]
# # Ignorar

# %%
# Valor específico
#valor_especifico = 'BENIGN'

# Coleta de valores diferentes do valor específico
#valores_diferentes = df.loc[df['Label'] != valor_especifico, 'Label'].tolist()

#print(valores_diferentes)

# %%
#pd.set_option('display.max_rows', None)
#contagem_valores = df['Label'].value_counts()
#print(contagem_valores)

# %%
#df['Z'] = df['X'] + df['Y']

# Apagar as colunas X e Y
#df.drop(columns=['X', 'Y'], inplace=True)
